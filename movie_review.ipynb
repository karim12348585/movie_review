# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk import WordNetLemmatizer, SnowballStemmer
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
movies = pd.read_csv("IMDB Dataset.csv")
movies.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
movies["sentiment"].nunique()
# Out:
# 2

# %%
 # balanced dataset
movies["sentiment"].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
movies["review"][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %% [markdown]
# ## Text preprocessing

# %%
movies["review"][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %% [markdown]
# ## testing TF-IDF / Bag of words vectorization

# %%
from tqdm import tqdm

# %%
# Initialize stemmer and stopwords set
stemmer = SnowballStemmer("english")
stop_words = set(stopwords.words("english"))
corpus = []

# Use tqdm for a simple iterable loop
for review in tqdm(movies["review"].values, desc="Processing Reviews"):
    # Your review processing code here
    review = re.sub(r"[^a-zA-Z0-9]", " ", review.lower())
    tokens = nltk.word_tokenize(review)
    sent = [stemmer.stem(word) for word in tokens if word not in stop_words]
    corpus.append(sent)

print(f"Processed {len(corpus)} reviews!")
# Out:
# Processing Reviews: 100%|██████████| 50000/50000 [02:18<00:00, 360.62it/s]
# Processed 50000 reviews!

# %%
from sklearn.model_selection import train_test_split 
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score , classification_report

def naive_bayes_model(X1 , y1):
    X_train, X_test, y_train, y_test =  train_test_split(X1, y1, test_size=0.2, random_state=0)
    bayes_classifier = MultinomialNB().fit(X_train, y_train)
    y_pred = bayes_classifier.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    
    return bayes_classifier

# %%
# for continus features
from sklearn.naive_bayes import GaussianNB
def Gaussian_naive_bayes_model(X1, y1):
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=0)
    Gaussian_bayes_classifier = GaussianNB().fit(X_train, y_train)  # Use GaussianNB instead of MultinomialNB
    y_pred = Gaussian_bayes_classifier.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    
    return Gaussian_bayes_classifier

# %%
y1 = pd.get_dummies(movies["sentiment"])
y1= y1.iloc[:,1].values
y1
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X1 = cv.fit_transform(movies["review"])
print(X1.shape)
cv.vocabulary_
# Out:
# (50000, 101895)
# {'one': 64131,
#  'of': 63757,
#  'the': 90160,
#  'other': 64776,
#  'reviewers': 75511,
#  'has': 40745,
#  'mentioned': 57558,
#  'that': 90137,
#  'after': 2970,
#  'watching': 98226,
#  'just': 48473,
#  'oz': 65469,
#  'episode': 30113,
#  'you': 101096,
#  'll': 53223,
#  'be': 8758,
#  'hooked': 42850,
#  'they': 90347,
#  'are': 5707,
#  'right': 75915,
#  'as': 6166,
#  'this': 90455,
#  'is': 46765,
#  'exactly': 30975,
#  'what': 98847,
#  'happened': 40445,
#  'with': 99740,
#  'me': 56982,
#  'br': 12041,
#  'first': 33526,
#  'thing': 90399,
#  'struck': 86597,
#  'about': 1866,
#  'was': 98149,
#  'its': 46954,
#  'brutality': 12974,
#  'and': 4541,
#  'unflinching': 94620,
#  'scenes': 78746,
#  'violence': 97142,
#  'which': 98951,
#  'set': 80312,
#  'in': 44763,
#  'from': 35408,
#  'word': 100095,
#  'go': 37795,
#  'trust': 92962,
#  'not': 62917,
#  'show': 81437,
#  'for': 34443,
#  'faint': 31918,
#  'hearted': 41171,
#  'or': 64417,
#  'timid': 90979,
#  'pulls': 71592,
#  'no': 62551,
#  'punches': 71639,
#  'regards': 74108,
#  'to': 91217,
#  'drugs': 27443,
#  'sex': 80408,
#  'hardcore': 40507,
#  'classic': 17536,
#  'use': 95817,
#  'it': 46902,
#  'called': 14103,
#  'nickname': 62222,
#  'given': 37476,
#  'oswald': 64760,
#  'maximum': 56533,
#  'security': 79689,
#  'state': 85558,
#  'penitentary': 67071,
#  'focuses': 34246,
#  'mainly': 54982,
#  'on': 64110,
#  'emerald': 29258,
#  'city': 17382,
#  'an': 4414,
#  'experimental': 31370,
#  'section': 79668,
#  'prison': 70605,
#  'where': 98926,
#  'all': 3720,
#  'cells': 15580,
#  'have': 40913,
#  'glass': 37552,
#  'fronts': 35429,
#  'face': 31797,
#  'inwards': 46564,
#  'so': 83481,
#  'privacy': 70621,
#  'high': 41961,
#  'agenda': 3024,
#  'em': 29142,
#  'home': 42633,
#  'many': 55619,
#  'aryans': 6160,
#  'muslims': 60781,
#  'gangstas': 36216,
#  'latinos': 51580,
#  'christians': 16967,
#  'italians': 46911,
#  'irish': 46647,
#  'more': 59802,
#  'scuffles': 79429,
#  'death': 22972,
#  'stares': 85469,
#  'dodgy': 26380,
#  'dealings': 22942,
#  'shady': 80533,
#  'agreements': 3130,
#  'never': 62018,
#  'far': 32210,
#  'away': 7224,
#  'would': 100245,
#  'say': 78526,
#  'main': 54968,
#  'appeal': 5349,
#  'due': 27606,
#  'fact': 31842,
#  'goes': 37915,
#  'shows': 81472,
#  'wouldn': 100248,
#  'dare': 22603,
#  'forget': 34579,
#  'pretty': 70448,
#  'pictures': 68117,
#  'painted': 65674,
#  'mainstream': 54992,
#  'audiences': 6828,
#  'charm': 16119,
#  'romance': 76558,
#  'doesn': 26396,
#  'mess': 57756,
#  'around': 5948,
#  'ever': 30818,
#  'saw': 78495,
#  'nasty': 61396,
#  'surreal': 87821,
#  'couldn': 20608,
#  'ready': 73312,
#  'but': 13654,
#  'watched': 98219,
#  'developed': 24622,
#  'taste': 89187,
#  'got': 38303,
#  'accustomed': 2170,
#  'levels': 52433,
#  'graphic': 38604,
#  'injustice': 45622,
#  'crooked': 21451,
#  'guards': 39312,
#  'who': 99131,
#  'sold': 83702,
#  'out': 64852,
#  'nickel': 62203,
#  'inmates': 45643,
#  'kill': 49629,
#  'order': 64482,
#  'get': 37013,
#  'well': 98626,
#  'mannered': 55525,
#  'middle': 58082,
#  'class': 17532,
#  'being': 9211,
#  'turned': 93275,
#  'into': 46342,
#  'bitches': 10355,
#  'their': 90203,
#  'lack': 50948,
#  'street': 86413,
#  'skills': 82445,
#  'experience': 31362,
#  'may': 56540,
#  'become': 8960,
#  'comfortable': 18635,
#  'uncomfortable': 94097,
#  'viewing': 96963,
#  'thats': 90146,
#  'if': 44135,
#  'can': 14296,
#  'touch': 91774,
#  'your': 101124,
#  'darker': 22627,
#  'side': 81742,
#  'wonderful': 99947,
#  'little': 53140,
#  'production': 70771,
#  'filming': 33265,
#  'technique': 89451,
#  'very': 96714,
#  'unassuming': 93940,
#  'old': 63986,
#  'time': 90935,
#  'bbc': 8731,
#  'fashion': 32360,
#  'gives': 37479,
#  'comforting': 18638,
#  'sometimes': 83842,
#  'discomforting': 25528,
#  'sense': 80031,
#  'realism': 73341,
#  'entire': 29939,
#  'piece': 68138,
#  'actors': 2362,
#  'extremely': 31643,
#  'chosen': 16910,
#  'michael': 57985,
#  'sheen': 80872,
#  'only': 64162,
#  'polari': 69141,
#  'he': 41040,
#  'voices': 97429,
#  'down': 26971,
#  'pat': 66466,
#  'too': 91499,
#  'truly': 92933,
#  'see': 79728,
#  'seamless': 79527,
#  'editing': 28447,
#  'guided': 39393,
#  'by': 13767,
#  'references': 73980,
#  'williams': 99414,
#  'diary': 24883,
#  'entries': 29989,
#  'worth': 100225,
#  'terrificly': 89918,
#  'written': 100390,
#  'performed': 67259,
#  'masterful': 56221,
#  'great': 38740,
#  'master': 56213,
#  'comedy': 18610,
#  'his': 42211,
#  'life': 52654,
#  'really': 73365,
#  'comes': 18623,
#  'things': 90408,
#  'fantasy': 32192,
#  'guard': 39300,
#  'rather': 73069,
#  'than': 90108,
#  'traditional': 91990,
#  'dream': 27207,
#  'techniques': 89452,
#  'remains': 74503,
#  'solid': 83737,
#  'then': 90240,
#  'disappears': 25422,
#  'plays': 68763,
#  'our': 64837,
#  'knowledge': 50151,
#  'senses': 80037,
#  'particularly': 66319,
#  'concerning': 19145,
#  'orton': 64676,
#  'halliwell': 40115,
#  'sets': 80329,
#  'flat': 33773,
#  'murals': 60659,
#  'decorating': 23218,
#  'every': 30849,
#  'surface': 87754,
#  'terribly': 89911,
#  'done': 26611,
#  'thought': 90537,
#  'way': 98333,
#  'spend': 84543,
#  'hot': 43133,
#  'summer': 87338,
#  'weekend': 98490,
#  'sitting': 82277,
#  'air': 3271,
#  'conditioned': 19248,
#  'theater': 90172,
#  'light': 52699,
#  'plot': 68882,
#  'simplistic': 82046,
#  'dialogue': 24838,
#  'witty': 99803,
#  'characters': 16044,
#  'likable': 52745,
#  'even': 30792,
#  'bread': 12292,
#  'suspected': 87901,
#  'serial': 80224,
#  'killer': 49640,
#  'while': 98963,
#  'some': 83810,
#  'disappointed': 25425,
#  'when': 98921,
#  'realize': 73354,
#  'match': 56282,
#  'point': 69077,
#  'risk': 76083,
#  'addiction': 2456,
#  'proof': 70981,
#  'woody': 100026,
#  'allen': 3750,
#  'still': 85957,
#  'fully': 35614,
#  'control': 19966,
#  'style': 86786,
#  'us': 95800,
#  'grown': 39173,
#  'love': 53842,
#  'most': 60019,
#  'laughed': 51633,
#  'at': 6553,
#  'comedies': 18607,
#  'years': 100857,
#  'decade': 23070,
#  've': 96387,
#  'been': 9044,
#  'impressed': 44682,
#  'scarlet': 78675,
#  'johanson': 47999,
#  'she': 80841,
#  'managed': 55308,
#  'tone': 91458,
#  'her': 41628,
#  'sexy': 80453,
#  'image': 44330,
#  'jumped': 48392,
#  'average': 7119,
#  'spirited': 84691,
#  'young': 101107,
#  'woman': 99919,
#  'crown': 21539,
#  'jewel': 47752,
#  'career': 14696,
#  'wittier': 99796,
#  'devil': 24664,
#  'wears': 98407,
#  'prada': 69948,
#  'interesting': 46109,
#  'superman': 87559,
#  'friends': 35298,
#  'basically': 8472,
#  'there': 90288,
#  'family': 32082,
#  'boy': 11998,
#  'jake': 47217,
#  'thinks': 90417,
#  'zombie': 101690,
#  'closet': 17884,
#  'parents': 66161,
#  'fighting': 33155,
#  'movie': 60214,
#  'slower': 82936,
#  'soap': 83490,
#  'opera': 64289,
#  'suddenly': 87136,
#  'decides': 23141,
#  'rambo': 72780,
#  'ok': 63927,
#  're': 73259,
#  'going': 37943,
#  'make': 55054,
#  'film': 33226,
#  'must': 60801,
#  'decide': 23136,
#  'thriller': 90607,
#  'drama': 27115,
#  'watchable': 98213,
#  'divorcing': 26201,
#  'arguing': 5761,
#  'like': 52747,
#  'real': 73329,
#  'we': 98370,
#  'totally': 91742,
#  'ruins': 77180,
#  'expected': 31327,
#  'boogeyman': 11516,
#  'similar': 81987,
#  'instead': 45875,
#  'meaningless': 57020,
#  'spots': 84916,
#  '10': 57,
#  'playing': 68749,
#  'descent': 24281,
#  'dialogs': 24837,
#  'shots': 81400,
#  'ignore': 44184,
#  'them': 90222,
#  'petter': 67638,
#  'mattei': 56405,
#  'money': 59427,
#  'visually': 97285,
#  'stunning': 86722,
#  'watch': 98210,
#  'mr': 60302,
#  'offers': 63799,
#  'vivid': 97347,
#  'portrait': 69616,
#  'human': 43470,
#  'relations': 74381,
#  'seems': 79762,
#  'telling': 89644,
#  'power': 69880,
#  'success': 87070,
#  'do': 26273,
#  'people': 67138,
#  'different': 25023,
#  'situations': 82284,
#  'encounter': 29520,
#  'variation': 96284,
#  'arthur': 6079,
#  'schnitzler': 78943,
#  'play': 68722,
#  'same': 77913,
#  'theme': 90228,
#  'director': 25347,
#  'transfers': 92146,
#  'action': 2329,
#  'present': 70334,
#  'new': 62038,
#  'york': 101062,
#  'these': 90322,
#  'meet': 57214,
#  'connect': 19483,
#  'each': 28107,
#  'connected': 19484,
#  'another': 4918,
#  'next': 62129,
#  'person': 67435,
#  'know': 50143,
#  'previous': 70477,
#  'contact': 19768,
#  'stylishly': 86796,
#  'sophisticated': 83976,
#  'luxurious': 54299,
#  'look': 53579,
#  'taken': 88780,
#  'how': 43255,
#  'live': 53157,
#  'world': 100161,
#  'own': 65431,
#  'habitat': 39837,
#  'gets': 37025,
#  'souls': 84114,
#  'picture': 68115,
#  'stages': 85260,
#  'loneliness': 53512,
#  'inhabits': 45547,
#  'big': 10033,
#  'best': 9747,
#  'place': 68560,
#  'find': 33355,
#  'sincere': 82084,
#  'fulfillment': 35592,
#  'discerns': 25491,
#  'case': 15040,
#  'acting': 2324,
#  'good': 38092,
#  'under': 94217,
#  'direction': 25338,
#  'steve': 85881,
#  'buscemi': 13575,
#  'rosario': 76740,
#  'dawson': 22832,
#  'carol': 14853,
#  'kane': 48762,
#  'imperioli': 44554,
#  'adrian': 2682,
#  'grenier': 38852,
#  'rest': 75200,
#  'talented': 88820,
#  'cast': 15118,
#  'come': 18596,
#  'alive': 3710,
#  'wish': 99686,
#  'luck': 54019,
#  'await': 7200,
#  'anxiously': 5149,
#  'work': 100120,
#  'probably': 70672,
#  'my': 60906,
#  'favorite': 32503,
#  'story': 86211,
#  'selflessness': 79887,
#  'sacrifice': 77568,
#  'dedication': 23259,
#  'noble': 62565,
#  'cause': 15373,
#  'preachy': 70030,
#  'boring': 11720,
#  'despite': 24418,
#  'having': 40928,
#  'seen': 79764,
#  '15': 234,
#  'times': 90961,
#  'last': 51521,
#  '25': 770,
#  'paul': 66623,
#  'lukas': 54095,
#  'performance': 67255,
#  'brings': 12602,
#  'tears': 89414,
#  'eyes': 31711,
#  'bette': 9804,
#  'davis': 22806,
#  'few': 33002,
#  'sympathetic': 88399,
#  'roles': 76512,
#  'delight': 23669,
#  'kids': 49566,
#  'grandma': 38554,
#  'says': 78543,
#  'dressed': 27279,
#  'up': 95593,
#  'midgets': 58103,
#  'children': 16634,
#  'makes': 55064,
#  'fun': 35638,
#  'mother': 60046,
#  'slow': 82931,
#  'awakening': 7207,
#  'happening': 40447,
#  'roof': 76654,
#  'believable': 9286,
#  'startling': 85535,
#  'had': 39880,
#  'dozen': 27037,
#  'thumbs': 90705,
#  'sure': 87742,
#  'resurrection': 75273,
#  'dated': 22738,
#  'seahunt': 79511,
#  'series': 80231,
#  'tech': 89432,
#  'today': 91256,
#  'bring': 12597,
#  'back': 7490,
#  'kid': 49531,
#  'excitement': 31081,
#  'grew': 38870,
#  'black': 10436,
#  'white': 99056,
#  'tv': 93369,
#  'gunsmoke': 39592,
#  'were': 98693,
#  'hero': 41711,
#  'week': 98487,
#  'vote': 97548,
#  'comeback': 18597,
#  'sea': 79484,
#  'hunt': 43625,
#  'need': 61705,
#  'change': 15939,
#  'pace': 65521,
#  'water': 98239,
#  'adventure': 2733,
#  'oh': 63873,
#  'thank': 90117,
#  'outlet': 64932,
#  'view': 96955,
#  'viewpoints': 96967,
#  'movies': 60244,
#  'any': 5151,
#  'ole': 64009,
#  'believe': 9288,
#  'wanna': 98007,
#  'nice': 62174,
#  'read': 73290,
#  'plus': 68969,
#  'points': 69093,
#  'rhymes': 75705,
#  'lines': 52918,
#  'let': 52367,
#  'submit': 86921,
#  'leave': 51925,
#  'doubt': 26904,
#  'quit': 72323,
#  'lets': 52388,
#  'amazing': 4123,
#  'fresh': 35223,
#  'innovative': 45688,
#  'idea': 44026,
#  '70': 1242,
#  'aired': 3285,
#  'brilliant': 12577,
#  'dropped': 27395,
#  'off': 63765,
#  '1990': 565,
#  'funny': 35710,
#  'anymore': 5163,
#  'continued': 19875,
#  'decline': 23184,
#  'further': 35768,
#  'complete': 18941,
#  'waste': 98190,
#  'disgraceful': 25663,
#  'fallen': 32009,
#  'writing': 100387,
#  'painfully': 65662,
#  'bad': 7584,
#  'performances': 67256,
#  'almost': 3877,
#  'mildly': 58258,
#  'entertaining': 29907,
#  'respite': 75168,
#  'guest': 39362,
#  'hosts': 43132,
#  'hard': 40497,
#  'creator': 21121,
#  'hand': 40268,
#  'selected': 79867,
#  'original': 64584,
#  'also': 3945,
#  'chose': 16909,
#  'band': 7987,
#  'hacks': 39874,
#  'followed': 34329,
#  'recognize': 73635,
#  'such': 87097,
#  'brilliance': 12575,
#  'fit': 33587,
#  'replace': 74819,
#  'mediocrity': 57157,
#  'felt': 32768,
#  'give': 37472,
#  'stars': 85518,
#  'respect': 75150,
#  'made': 54694,
#  'huge': 43411,
#  'now': 63040,
#  'awful': 7242,
#  'encouraged': 29527,
#  'positive': 69674,
#  'comments': 18723,
#  'here': 41658,
#  'looking': 53587,
#  'forward': 34733,
#  'mistake': 58929,
#  '950': 1401,
#  'films': 33290,
#  'worst': 100223,
#  'pacing': 65550,
#  'storyline': 86222,
#  'soundtrack': 84144,
#  'song': 83895,
#  'lame': 51161,
#  'country': 20696,
#  'tune': 93177,
#  'played': 68732,
#  'less': 52348,
#  'four': 34802,
#  'looks': 53592,
#  'cheap': 16254,
#  'extreme': 31641,
#  'rarely': 72998,
#  'happy': 40462,
#  'end': 29553,
#  'credits': 21146,
#  'prevents': 70470,
#  'giving': 37481,
#  'score': 79171,
#  'harvey': 40738,
#  'keitel': 49211,
#  'least': 51906,
#  'making': 55074,
#  'bit': 10351,
#  'effort': 28594,
#  'obsessives': 63538,
#  'gut': 39650,
#  'wrenching': 100329,
#  'laughter': 51644,
#  'will': 99392,
#  'hell': 41434,
#  'mom': 59364,
#  'liked': 52751,
#  'camp': 14244,
#  'phil': 67801,
#  'alien': 3665,
#  'those': 90530,
#  'quirky': 72316,
#  'humour': 43556,
#  'based': 8438,
#  'oddness': 63704,
#  'everything': 30863,
#  'actual': 2369,
#  'punchlines': 71644,
#  'odd': 63694,
#  'progressed': 70866,
#  'didn': 24979,
#  'jokes': 48053,
#  'low': 53891,
#  'budget': 13122,
#  'problem': 70690,
#  'itself': 46955,
#  'eventually': 30813,
#  'lost': 53734,
#  'interest': 46105,
#  'imagine': 44346,
#  'stoner': 86125,
#  'currently': 21943,
#  'partaking': 66284,
#  'something': 83836,
#  'better': 9805,
#  'try': 92983,
#  'brother': 12842,
#  'planet': 68623,
#  '12': 151,
#  'came': 14187,
#  'recall': 73516,
#  'scariest': 78667,
#  'scene': 78739,
#  'bird': 10268,
#  'eating': 28246,
#  'men': 57456,
#  'dangling': 22515,
#  'helplessly': 41504,
#  'parachutes': 66021,
#  'horror': 43030,
#  'cheesy': 16366,
#  'saturday': 78386,
#  'afternoons': 2981,
#  'tired': 91087,
#  'formula': 34646,
#  'monster': 59560,
#  'type': 93535,
#  'usually': 95855,
#  'included': 44921,
#  'beautiful': 8899,
#  'might': 58161,
#  'daughter': 22760,
#  'professor': 70803,
#  'resolution': 75117,
#  'died': 24984,
#  'care': 14689,
#  'much': 60359,
#  'romantic': 76575,
#  'angle': 4699,
#  'year': 100845,
#  'predictable': 70127,
#  'plots': 68892,
#  'unintentional': 94843,
#  'humor': 43546,
#  'later': 51552,
#  'psycho': 71389,
#  'loved': 53851,
#  'star': 85443,
#  'janet': 47287,
#  'leigh': 52126,
#  'bumped': 13339,
#  'early': 28151,
#  'sat': 78300,
#  'took': 91503,
#  'notice': 62952,
#  'since': 82083,
#  'screenwriters': 79321,
#  'scary': 78693,
#  'possible': 69705,
#  'worn': 100191,
#  'rules': 77195,
#  'im': 44326,
#  'fan': 32094,
#  'boll': 11322,
#  'again': 3004,
#  'enjoyed': 29745,
#  'postal': 69710,
#  'maybe': 56550,
#  'apparently': 5340,
#  'bought': 11864,
#  'rights': 75931,
#  'cry': 21655,
#  'long': 53524,
#  'ago': 3098,
#  'before': 9098,
#  'game': 36139,
#  'finsished': 33445,
#  'killing': 49647,
#  'mercs': 57618,
#  'infiltrating': 45400,
#  'secret': 79648,
#  'research': 75014,
#  'labs': 50923,
#  'located': 53329,
#  'tropical': 92819,
#  'island': 46833,
#  'should': 81407,
#  'warned': 98094,
#  'schemed': 78815,
#  'together': 91291,
#  'along': 3894,
#  'legion': 52071,
#  'schmucks': 78929,
#  'feeling': 32663,
#  'loneley': 53509,
#  'invites': 46538,
#  'three': 90584,
#  'countrymen': 20699,
#  'players': 68734,
#  'names': 61214,
#  'til': 90893,
#  'schweiger': 79077,
#  'udo': 93657,
#  'kier': 49579,
#  'ralf': 72750,
#  'moeller': 59227,
#  'actually': 2375,
#  'selfs': 79890,
#  'biz': 10391,
#  'tale': 88817,
#  'jack': 47080,
#  'carver': 15013,
#  'yes': 100929,
#  'german': 36946,
#  'hail': 39980,
#  'bratwurst': 12231,
#  'dudes': 27595,
#  'however': 43269,
#  'tils': 90912,
#  'badass': 7590,
#  'complained': 18926,
#  'staying': 85625,
#  'true': 92910,
#  'whole': 99139,
#  'perspective': 67471,
#  'don': 26582,
#  'looked': 53582,
#  'kicking': 49526,
#  'beyond': 9874,
#  'demented': 23788,
#  'evil': 30894,
#  'mad': 54659,
#  'scientist': 79105,
#  'dr': 27053,
#  'krieger': 50527,
#  'genetically': 36766,
#  'mutated': 60829,
#  'soldiers': 83711,
#  'gms': 37771,
#  'performing': 67262,
#  'top': 91551,
#  'reminds': 74564,
#  'spoiler': 84801,
#  'vancouver': 96173,
#  'reason': 73417,
#  'palm': 65778,
#  'trees': 92446,
#  'rich': 75749,
#  'lumberjack': 54120,
#  'woods': 100010,
#  'haven': 40916,
#  'gone': 38067,
#  'started': 85527,
#  'mehehe': 57270,
#  'cannot': 14416,
#  'stay': 85621,
#  'bolls': 11333,
#  'shenanigans': 80955,
#  'delivers': 23702,
#  'meaning': 57014,
#  'suck': 87104,
#  'mentioning': 57559,
#  'imply': 44628,
#  'did': 24962,
#  'areas': 5711,
#  'boat': 11082,
#  'until': 95475,
#  'cromed': 21427,
#  'albino': 3513,
#  'squad': 85050,
#  'enters': 29897,
#  'laugh': 51630,
#  'reeks': 73934,
#  'scheisse': 78804,
#  'poop': 69418,
#  'simpletons': 82035,
#  'fa': 31754,
#  'take': 88771,
#  'wiff': 99301,
#  'ahead': 3173,
#  'btw': 13028,
#  'annoying': 4888,
#  'sidekick': 81752,
#  'shoot': 81318,
#  'him': 42092,
#  'minutes': 58608,
#  'screen': 79301,
#  'shakespeare': 80577,
#  'appreciate': 5454,
#  'trying': 92988,
#  'masses': 56187,
#  'why': 99207,
#  'ruin': 77173,
#  'because': 8929,
#  'scottish': 79210,
#  'certain': 15714,
#  'rev': 75429,
#  'bowdler': 11942,
#  'hence': 41553,
#  'bowdlerization': 11945,
#  'tried': 92607,
#  'victorian': 96862,
#  'era': 30205,
#  'words': 100108,
#  'improve': 44720,
#  'perfection': 67232,
#  'write': 100375,
#  'ten': 89719,
#  'text': 90054,
#  'english': 29693,
#  'composition': 19010,
#  'forte': 34691,
#  'keep': 49173,
#  'saying': 78535,
#  'does': 26394,
#  'cut': 22034,
#  'fantastic': 32183,
#  'prisoners': 70608,
#  'famous': 32092,
#  'george': 36889,
#  'clooney': 17871,
#  'roll': 76517,
#  'man': 55304,
#  'constant': 19686,
#  'sorrow': 84051,
#  'recommand': 73660,
#  'everybody': 30853,
#  'greetings': 38824,
#  'bart': 8392,
#  'kind': 49707,
#  'drawn': 27184,
#  'erotic': 30308,
#  'amateurish': 4103,
#  'unbelievable': 93989,
#  'bits': 10370,
#  'sort': 84056,
#  'school': 78969,
#  'project': 70887,
#  'rosanna': 76737,
#  'arquette': 5959,
#  'thinking': 90416,
#  'stock': 86056,
#  'bizarre': 10393,
#  'supposed': 87684,
#  'midwest': 58140,
#  'town': 91865,
#  'involved': 46553,
#  'lessons': 52357,
#  'learned': 51888,
#  'insights': 45794,
#  'stilted': 85970,
#  'quite': 72324,
#  'ridiculous': 75840,
#  'lots': 53753,
#  'skin': 82460,
#  'intrigues': 46381,
#  'videotaped': 96907,
#  'nonsense': 62742,
#  'bisexual': 10326,
#  'relationship': 74382,
#  'nowhere': 63045,
#  'heterosexual': 41823,
#  'encounters': 29524,
#  'absurd': 1961,
#  'dance': 22460,
#  'stereotyped': 85842,
#  'pass': 66386,
#  'million': 58356,
#  'miles': 58267,
#  'wasted': 98192,
#  'could': 20605,
#  'spent': 84551,
#  'starving': 85545,
#  'aids': 3221,
#  'africa': 2950,
#  'simply': 82048,
#  'remade': 74493,
#  'fails': 31913,
#  'capture': 14604,
#  'flavor': 33819,
#  'terror': 89934,
#  '1963': 521,
#  'title': 91142,
#  'liam': 52520,
#  'neeson': 61727,
#  'excellent': 31039,
#  'always': 4037,
#  'holds': 42497,
#  'exception': 31050,
#  'owen': 65424,
#  'wilson': 99455,
#  'feel': 32659,
#  'character': 16022,
#  'luke': 54097,
#  'major': 55035,
#  'fault': 32470,
#  'version': 96691,
#  'strayed': 86389,
#  'shirley': 81183,
#  'jackson': 47117,
#  'attempts': 6722,
#  'grandiose': 38548,
#  'thrill': 90605,
#  ...}

# %%
naive_bayes_model(X1,y1)
# Out:
# 0.8442
#               precision    recall  f1-score   support
#
#        False       0.82      0.88      0.85      5035
#         True       0.87      0.81      0.84      4965
#
#     accuracy                           0.84     10000
#    macro avg       0.85      0.84      0.84     10000
# weighted avg       0.85      0.84      0.84     10000
# MultinomialNB()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X2 = tfidf.fit_transform(movies["review"])
print(X2.shape)
X2
# Out:
# (50000, 101895)
# <50000x101895 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6826529 stored elements in Compressed Sparse Row format>

# %%
naive_bayes_model(X2 , y1)
# Out:
# 0.8618
#               precision    recall  f1-score   support
#
#        False       0.85      0.89      0.87      5035
#         True       0.88      0.84      0.86      4965
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
# MultinomialNB()

# %% [markdown]
# # Testing Word2Vec

# %%
import gensim

# %%
# training Word2vec cbow model  from scratch 
model = gensim.models.Word2Vec(corpus , min_count= 2 , window=5 ,vector_size=150)

# %%
# Extracting the embedding matrix
embedding_matrix = np.zeros((len(model.wv), model.vector_size))

# Populate the embedding matrix
for i, word in enumerate(model.wv.index_to_key):
    embedding_matrix[i] = model.wv[word]
embedding_matrix[0]
# Out:
# array([-1.45579875e+00,  5.21815717e-01,  6.49187863e-02,  3.64712358e-01,
#        -5.77859163e-01,  3.76251072e-01, -9.71547049e-03,  1.58895743e+00,
#        -1.17577851e+00,  1.05337453e+00,  1.13063037e+00, -1.22830319e+00,
#        -4.59179193e-01,  9.55084920e-01, -8.76758039e-01, -4.59074497e-01,
#         4.16691780e-01,  5.54818630e-01, -1.02391028e+00, -1.33414280e+00,
#         2.86422342e-01, -8.78238440e-01,  5.37320912e-01, -3.86113822e-01,
#        -4.09302533e-01, -9.09711346e-02, -5.51654577e-01, -1.67350173e-01,
#         3.74846250e-01, -7.64800370e-01, -2.36731827e-01,  1.02887833e+00,
#         4.67065573e-01, -3.86504799e-01,  5.79262674e-01,  6.81369454e-02,
#         3.44045907e-01,  9.43597183e-02, -2.33599156e-01,  1.90742582e-01,
#         1.67468712e-01,  7.44840086e-01,  6.86025560e-01, -2.85680085e-01,
#        -4.12607670e-01, -4.18745816e-01, -9.76781487e-01,  6.80891991e-01,
#        -7.66358197e-01, -3.95425456e-03, -1.10035336e+00,  1.47772223e-01,
#         1.44287229e+00,  1.16551888e+00,  1.22725442e-02, -1.20010424e+00,
#         7.91385323e-02, -3.33031654e-01,  1.70922920e-01, -4.86311257e-01,
#         6.36712253e-01,  4.10447001e-01, -1.01564240e+00, -1.22506964e+00,
#        -1.51417917e-02, -9.23846781e-01, -8.58916759e-01, -4.74125534e-01,
#        -1.20214731e-01,  6.28026351e-02, -6.27968609e-01,  3.34476709e-01,
#         3.99416655e-01, -4.71396372e-02,  1.53655207e+00, -7.77618289e-01,
#         1.01497185e+00,  6.68041170e-01,  1.14385343e+00, -5.78502893e-01,
#         4.72618759e-01, -7.85044059e-02, -1.37596035e+00, -5.17364085e-01,
#        -4.31162268e-01, -7.38190651e-01, -2.24875316e-01, -1.00616145e+00,
#        -8.94416392e-01,  8.91347051e-01, -1.68434429e+00,  2.37015039e-01,
#         8.04763079e-01,  5.11829495e-01,  3.82048339e-01,  3.98535013e-01,
#        -1.91210139e+00, -7.33272493e-01, -1.10437192e-01,  2.11865932e-01,
#        -8.10880303e-01, -1.76763797e+00,  5.28653920e-01, -1.53289244e-01,
#         3.60505849e-01, -3.52805406e-01,  8.03526163e-01,  1.26809323e+00,
#         8.00522268e-01, -6.36609554e-01,  9.19178426e-02, -1.83129299e+00,
#         7.57028908e-02,  3.82844925e-01,  7.56830394e-01,  1.41589403e+00,
#        -1.20883286e-01,  5.08221626e-01, -3.50871801e-01,  1.69855371e-01,
#         3.96748126e-01, -5.82791626e-01, -9.05213356e-01, -1.06636107e+00,
#        -3.12920451e-01,  1.35558486e+00, -1.53993383e-01,  1.23857033e+00,
#         4.43669140e-01, -8.94027770e-01,  7.26197660e-01,  1.70138001e-01,
#         2.32060224e-01, -2.13951379e-01,  9.54126239e-01,  4.05851007e-01,
#        -1.89387023e-01,  7.72347271e-01,  1.07131755e+00,  1.18332671e-03,
#         6.23583421e-02, -2.52729237e-01,  3.28663439e-01, -6.02325797e-01,
#        -1.26717269e+00, -1.03770900e+00,  7.47378051e-01, -1.34107578e+00,
#         6.25726044e-01, -3.49762231e-01])

# %%
model.wv.most_similar("love")
# Out:
# [('ador', 0.5009018182754517),
#  ('hate', 0.4869915544986725),
#  ('asleep', 0.4843272566795349),
#  ('touch', 0.47324052453041077),
#  ('lover', 0.4598483741283417),
#  ('friendship', 0.4596560001373291),
#  ('happi', 0.4467249810695648),
#  ('romanc', 0.4459366500377655),
#  ('apart', 0.4414093792438507),
#  ('sweet', 0.4391103684902191)]

# %%
model.wv.most_similar("hate")
# Out:
# [('dislik', 0.662932813167572),
#  ('despis', 0.6575043201446533),
#  ('complain', 0.5160329341888428),
#  ('offend', 0.5131930112838745),
#  ('disagre', 0.4923933148384094),
#  ('love', 0.4869915246963501),
#  ('afraid', 0.48119625449180603),
#  ('spoil', 0.4759232997894287),
#  ('suck', 0.47455722093582153),
#  ('think', 0.47109416127204895)]

# %%
# vocabulary
model.wv.index_to_key
# Out:
# ['br',
#  'movi',
#  'film',
#  'one',
#  'like',
#  'time',
#  'good',
#  'make',
#  'charact',
#  'see',
#  'get',
#  'watch',
#  'even',
#  'stori',
#  'would',
#  'realli',
#  'well',
#  'scene',
#  'look',
#  'show',
#  'bad',
#  'much',
#  'end',
#  'great',
#  'peopl',
#  'love',
#  'go',
#  'also',
#  'first',
#  'think',
#  'act',
#  'play',
#  'way',
#  'thing',
#  'made',
#  'could',
#  'know',
#  'say',
#  'seem',
#  'work',
#  'plot',
#  'actor',
#  'two',
#  'mani',
#  'seen',
#  'come',
#  'year',
#  'want',
#  'take',
#  'never',
#  'life',
#  'best',
#  'tri',
#  'littl',
#  'ever',
#  'man',
#  'better',
#  'give',
#  'still',
#  'find',
#  'perform',
#  'part',
#  'feel',
#  'use',
#  'someth',
#  'director',
#  'actual',
#  'back',
#  'interest',
#  'lot',
#  'real',
#  'guy',
#  'old',
#  'funni',
#  'cast',
#  'though',
#  'live',
#  '10',
#  'anoth',
#  'music',
#  'enjoy',
#  'star',
#  'noth',
#  'role',
#  'start',
#  'new',
#  'point',
#  'set',
#  'everi',
#  'girl',
#  'day',
#  'believ',
#  'direct',
#  'world',
#  'origin',
#  'turn',
#  'thought',
#  'horror',
#  'quit',
#  'comedi',
#  'minut',
#  'kill',
#  'us',
#  'fact',
#  'pretti',
#  'effect',
#  'got',
#  'action',
#  'happen',
#  'around',
#  'wonder',
#  'right',
#  'long',
#  'young',
#  'big',
#  'howev',
#  'friend',
#  'enough',
#  'line',
#  'fan',
#  'high',
#  'may',
#  'need',
#  'bit',
#  'person',
#  'seri',
#  'script',
#  'must',
#  'beauti',
#  'hard',
#  'without',
#  'famili',
#  'saw',
#  'alway',
#  'reason',
#  'kid',
#  'put',
#  'becom',
#  'tell',
#  'almost',
#  'last',
#  'final',
#  'laugh',
#  'done',
#  'complet',
#  'whole',
#  'least',
#  'sure',
#  'kind',
#  'shot',
#  'far',
#  'place',
#  'expect',
#  'differ',
#  'name',
#  'mean',
#  '2',
#  'call',
#  'might',
#  'anyth',
#  'sinc',
#  'book',
#  'let',
#  'tv',
#  'probabl',
#  'screen',
#  'begin',
#  'entertain',
#  'help',
#  'away',
#  'yet',
#  'moment',
#  'main',
#  'woman',
#  'fun',
#  'anyon',
#  'run',
#  'american',
#  'lead',
#  'worst',
#  'read',
#  'rather',
#  'poor',
#  'audienc',
#  'idea',
#  'found',
#  'bore',
#  'war',
#  'keep',
#  'appear',
#  'hope',
#  'although',
#  'especi',
#  'episod',
#  'dvd',
#  'surpris',
#  'cours',
#  'move',
#  'everyth',
#  'sens',
#  'job',
#  'perfect',
#  'goe',
#  'mayb',
#  'mind',
#  'second',
#  'three',
#  'worth',
#  'recommend',
#  'sound',
#  'someon',
#  'face',
#  'product',
#  'problem',
#  'night',
#  'follow',
#  'certain',
#  'boy',
#  'money',
#  'version',
#  'true',
#  'special',
#  'rate',
#  'everyon',
#  'human',
#  'nice',
#  'togeth',
#  'short',
#  'excel',
#  'leav',
#  'suppos',
#  'view',
#  'obvious',
#  'black',
#  'hand',
#  'wast',
#  'open',
#  'death',
#  'hous',
#  'eye',
#  'instead',
#  '1',
#  'half',
#  'understand',
#  'said',
#  'hour',
#  'classic',
#  'review',
#  'anim',
#  'talk',
#  'later',
#  'john',
#  'miss',
#  'head',
#  'care',
#  'left',
#  'serious',
#  'die',
#  'wife',
#  'write',
#  'murder',
#  'dead',
#  'chang',
#  'budget',
#  'father',
#  'rememb',
#  'total',
#  'els',
#  'stupid',
#  'top',
#  'involv',
#  'piec',
#  'includ',
#  'fight',
#  'viewer',
#  'entir',
#  'releas',
#  'fall',
#  'terribl',
#  'home',
#  'simpli',
#  '3',
#  'pictur',
#  'power',
#  'men',
#  'coupl',
#  'attempt',
#  'camera',
#  'usual',
#  'produc',
#  'disappoint',
#  'less',
#  'wrong',
#  'along',
#  'featur',
#  'video',
#  'song',
#  'portray',
#  'low',
#  'word',
#  'aw',
#  'possibl',
#  'hollywood',
#  'school',
#  'absolut',
#  'either',
#  'definit',
#  'lack',
#  'decid',
#  'except',
#  'talent',
#  'titl',
#  'women',
#  'given',
#  'rest',
#  'full',
#  'emot',
#  'next',
#  'game',
#  'writer',
#  'particular',
#  'sex',
#  'style',
#  'truli',
#  'save',
#  'clear',
#  'close',
#  'amaz',
#  'sort',
#  'mother',
#  'comment',
#  'sever',
#  'joke',
#  'case',
#  'bring',
#  'came',
#  'dialogu',
#  'flick',
#  'heart',
#  'humor',
#  'perhap',
#  'creat',
#  'dark',
#  'base',
#  'sad',
#  'age',
#  'art',
#  'near',
#  'small',
#  'guess',
#  'other',
#  'stop',
#  'meet',
#  'sequenc',
#  'experi',
#  'light',
#  'earli',
#  'often',
#  'brother',
#  'drama',
#  'forc',
#  'written',
#  'children',
#  'killer',
#  'mention',
#  'consid',
#  'actress',
#  'cinema',
#  'exampl',
#  'side',
#  'cut',
#  'qualiti',
#  'car',
#  'unfortun',
#  'develop',
#  'went',
#  'manag',
#  'yes',
#  'imagin',
#  'oh',
#  'horribl',
#  'lost',
#  'extrem',
#  'wors',
#  'matter',
#  'white',
#  'hit',
#  'ask',
#  'present',
#  'voic',
#  'fail',
#  'brilliant',
#  'overal',
#  'impress',
#  'natur',
#  'felt',
#  'mr',
#  'son',
#  '5',
#  'stand',
#  'basic',
#  'type',
#  '4',
#  'favorit',
#  'hero',
#  'support',
#  'evil',
#  'wait',
#  'learn',
#  'despit',
#  'alreadi',
#  'throughout',
#  'danc',
#  'walk',
#  'relationship',
#  'number',
#  'genr',
#  'question',
#  'deal',
#  'abl',
#  'fine',
#  'hate',
#  'michael',
#  'b',
#  'histori',
#  'mysteri',
#  'town',
#  'god',
#  'rent',
#  'success',
#  'today',
#  'daughter',
#  'credit',
#  'wish',
#  'strong',
#  'late',
#  'twist',
#  'past',
#  'deserv',
#  'sit',
#  'citi',
#  'import',
#  'group',
#  'score',
#  'pleas',
#  'theme',
#  'anyway',
#  'annoy',
#  'child',
#  'sometim',
#  'touch',
#  'edit',
#  'stay',
#  'event',
#  'etc',
#  'general',
#  'situat',
#  'realiz',
#  'stuff',
#  'level',
#  'behind',
#  'robert',
#  'gave',
#  'appar',
#  'bodi',
#  'major',
#  'hilari',
#  'add',
#  'exact',
#  'blood',
#  'chanc',
#  'order',
#  'soon',
#  'incred',
#  'slow',
#  'return',
#  'decent',
#  'pace',
#  'comic',
#  'ridicul',
#  'relat',
#  'self',
#  'speak',
#  'continu',
#  'figur',
#  'shoot',
#  'thank',
#  'known',
#  'took',
#  'heard',
#  'fair',
#  'element',
#  'monster',
#  'countri',
#  'career',
#  'pick',
#  'documentari',
#  'strang',
#  'clich',
#  'happi',
#  'novel',
#  'critic',
#  'polic',
#  'pain',
#  'husband',
#  'suspens',
#  'predict',
#  'told',
#  'break',
#  'violenc',
#  'convinc',
#  'cool',
#  'dream',
#  'similar',
#  'realiti',
#  'recent',
#  'state',
#  'compar',
#  'crap',
#  'ok',
#  'hold',
#  'visual',
#  'caus',
#  'effort',
#  'hell',
#  'opinion',
#  'sister',
#  'zombi',
#  'offer',
#  'david',
#  'gore',
#  'shock',
#  'simpl',
#  'sequel',
#  'provid',
#  'room',
#  'result',
#  'deliv',
#  'jame',
#  'ladi',
#  'huge',
#  'theater',
#  'explain',
#  'local',
#  'ago',
#  'femal',
#  'thriller',
#  'shown',
#  'taken',
#  'cop',
#  'english',
#  'allow',
#  'valu',
#  'dog',
#  'hear',
#  'check',
#  'buy',
#  'exist',
#  'note',
#  'subject',
#  'silli',
#  'alon',
#  'across',
#  'spoiler',
#  'none',
#  'offic',
#  'quick',
#  'team',
#  'class',
#  'rock',
#  'confus',
#  'dialog',
#  'cinematographi',
#  'avoid',
#  'sexual',
#  'polit',
#  'focus',
#  'cover',
#  'whose',
#  'jack',
#  'middl',
#  'excit',
#  'honest',
#  'win',
#  'season',
#  'apart',
#  'parent',
#  'build',
#  'four',
#  'modern',
#  'messag',
#  'scari',
#  'form',
#  'pull',
#  'tale',
#  'filmmak',
#  'carri',
#  'most',
#  'attent',
#  'beyond',
#  'televis',
#  'singl',
#  'escap',
#  'pass',
#  'somewhat',
#  'street',
#  'pay',
#  'knew',
#  'cheap',
#  'king',
#  'drug',
#  'train',
#  'fill',
#  'charm',
#  'detail',
#  'non',
#  'unlik',
#  'earth',
#  'due',
#  'upon',
#  'western',
#  'imag',
#  'typic',
#  'respect',
#  'remind',
#  'william',
#  'member',
#  'fit',
#  'villain',
#  'toward',
#  'oscar',
#  'gun',
#  'space',
#  'georg',
#  'crime',
#  'doubt',
#  'sing',
#  'prove',
#  'remain',
#  'fire',
#  '7',
#  'stage',
#  'drive',
#  'ten',
#  'weak',
#  'air',
#  'intellig',
#  'five',
#  'british',
#  'discov',
#  'marri',
#  'atmospher',
#  'french',
#  'plan',
#  'narrat',
#  'artist',
#  'alien',
#  'straight',
#  'fast',
#  'romant',
#  'realist',
#  'soundtrack',
#  'captur',
#  'futur',
#  'date',
#  '8',
#  'appreci',
#  'previous',
#  'whether',
#  'box',
#  'posit',
#  'odd',
#  'spend',
#  'notic',
#  'mark',
#  'admit',
#  'teenag',
#  'forget',
#  'peter',
#  'richard',
#  'easili',
#  'attack',
#  'dull',
#  'ad',
#  'chase',
#  'fantast',
#  'aspect',
#  'soldier',
#  'doctor',
#  'adult',
#  'within',
#  'copi',
#  'battl',
#  'bunch',
#  'e',
#  'period',
#  'master',
#  'victim',
#  'materi',
#  'easi',
#  'accept',
#  'storylin',
#  'agre',
#  'suck',
#  'adapt',
#  'inspir',
#  'secret',
#  'sorri',
#  'bill',
#  'locat',
#  'water',
#  'truth',
#  'standard',
#  'color',
#  'larg',
#  'among',
#  'list',
#  'student',
#  'gone',
#  'suggest',
#  'busi',
#  '9',
#  'dr',
#  'eventu',
#  'mess',
#  'lose',
#  'match',
#  'finish',
#  'famous',
#  'issu',
#  'cartoon',
#  'contain',
#  'okay',
#  'throw',
#  'suffer',
#  'cultur',
#  'reveal',
#  'troubl',
#  'cri',
#  'red',
#  'kept',
#  'shame',
#  'vampir',
#  'greatest',
#  'adventur',
#  'dramat',
#  'paul',
#  'normal',
#  'romanc',
#  'wit',
#  'third',
#  'premis',
#  'utter',
#  'tom',
#  'sudden',
#  '20',
#  'attract',
#  'describ',
#  'mix',
#  'brought',
#  'ultim',
#  'somehow',
#  'week',
#  'refer',
#  'america',
#  'masterpiec',
#  'rare',
#  'male',
#  'averag',
#  'imdb',
#  'memor',
#  'prison',
#  'express',
#  'parti',
#  'bother',
#  'german',
#  'background',
#  'frank',
#  'gay',
#  'pure',
#  'societi',
#  'deep',
#  'lame',
#  'mad',
#  'fear',
#  'york',
#  'hot',
#  'babi',
#  'forward',
#  'spirit',
#  'fi',
#  'amus',
#  'free',
#  'sci',
#  'project',
#  'whatev',
#  'warn',
#  'treat',
#  'island',
#  'crew',
#  'inde',
#  'appeal',
#  'weird',
#  'scare',
#  'studio',
#  'choic',
#  'constant',
#  'wood',
#  'clever',
#  'slight',
#  'control',
#  'fiction',
#  'accent',
#  'lie',
#  'cheesi',
#  'screenplay',
#  'lee',
#  'design',
#  'fli',
#  'difficult',
#  'wear',
#  'rich',
#  'girlfriend',
#  'depict',
#  'footag',
#  'public',
#  'dumb',
#  'unless',
#  'de',
#  'crazi',
#  'uniqu',
#  'lover',
#  'award',
#  'becam',
#  'struggl',
#  'otherwis',
#  'costum',
#  'insid',
#  'flaw',
#  'grow',
#  'potenti',
#  'plus',
#  'scream',
#  'stereotyp',
#  'ride',
#  'connect',
#  'outsid',
#  'remak',
#  'superb',
#  'fantasi',
#  'moral',
#  'brain',
#  'magic',
#  'surviv',
#  'japanes',
#  'land',
#  'stick',
#  'creepi',
#  'execut',
#  'maker',
#  'bare',
#  '80',
#  'roll',
#  'harri',
#  'front',
#  'plenti',
#  'disney',
#  'disturb',
#  'teen',
#  'joe',
#  'mari',
#  'promis',
#  'steal',
#  'compani',
#  'popular',
#  'jump',
#  'eat',
#  'dress',
#  'track',
#  'earlier',
#  'post',
#  'beat',
#  'memori',
#  'term',
#  'catch',
#  'serv',
#  'inform',
#  'amount',
#  'answer',
#  'cat',
#  'older',
#  'plain',
#  'travel',
#  'concept',
#  'various',
#  'combin',
#  'listen',
#  'innoc',
#  'band',
#  'hair',
#  'equal',
#  'era',
#  'ghost',
#  'store',
#  'rip',
#  'record',
#  'italian',
#  'law',
#  'univers',
#  'c',
#  'centuri',
#  '30',
#  'blue',
#  'histor',
#  'spent',
#  'cute',
#  'kick',
#  'channel',
#  'creatur',
#  'concern',
#  'social',
#  'repeat',
#  'danger',
#  'sweet',
#  'intent',
#  'mistak',
#  'soul',
#  'meant',
#  'tast',
#  'hole',
#  'player',
#  'flat',
#  'purpos',
#  'destroy',
#  'collect',
#  'abil',
#  'languag',
#  'familiar',
#  'co',
#  'engag',
#  'intens',
#  'caught',
#  'depth',
#  'step',
#  'cold',
#  'ignor',
#  'camp',
#  'door',
#  'ann',
#  'share',
#  'sick',
#  'tension',
#  'nuditi',
#  'spot',
#  'park',
#  'extra',
#  'generat',
#  'respons',
#  'indian',
#  'achiev',
#  '6',
#  'fascin',
#  'fake',
#  'wild',
#  'pop',
#  'liter',
#  'wrote',
#  'introduc',
#  'embarrass',
#  'claim',
#  'van',
#  'former',
#  'desper',
#  'scott',
#  'reach',
#  'scienc',
#  'violent',
#  'common',
#  'limit',
#  'intrigu',
#  'race',
#  'suit',
#  'search',
#  'tone',
#  'sleep',
#  'drag',
#  'manner',
#  'arriv',
#  'gang',
#  'fashion',
#  'trash',
#  'immedi',
#  'cross',
#  'complex',
#  'tortur',
#  'million',
#  'approach',
#  'judg',
#  'drop',
#  'ruin',
#  ...]

# %%
# every word is associated to a 150 dim vector thanx to the embedding matrix W
print(model.wv["love"].shape)
model.wv["love"]
# Out:
# (150,)
# array([ 1.1522502e+00, -1.6956602e+00, -6.2574118e-01,  4.0677778e-02,
#        -1.9096283e+00, -4.8479107e-01, -1.5280989e+00, -2.7071598e-01,
#         1.2877877e-01, -4.0396857e-01, -1.3128494e-01, -6.1893322e-02,
#         1.3506856e+00,  1.2247601e+00, -9.3067312e-01, -1.2340944e-02,
#        -2.3092160e+00,  3.1086162e-01, -4.7584733e-01,  2.7380252e-01,
#        -5.2389777e-01,  6.4011657e-01,  3.0424383e+00, -8.9927459e-01,
#        -1.8285276e+00,  1.0825268e+00,  7.3879802e-01, -7.3065303e-02,
#        -1.1666458e+00,  1.1414434e+00,  1.5594392e+00, -2.7168099e-02,
#        -1.4950775e+00, -7.4620652e-01,  1.2359978e+00, -1.3189460e-01,
#         8.9568239e-01, -3.1382504e-01, -4.7846162e-01, -9.3360180e-01,
#         7.9774147e-01,  8.2574296e-01, -2.4820788e-01, -7.1443957e-01,
#         1.0444144e+00,  1.9651921e+00,  1.3165137e+00, -1.3672788e+00,
#        -7.6065439e-01,  3.7811583e-01, -1.0270007e+00, -1.0428925e+00,
#         8.7765448e-02,  9.5212877e-01, -1.5604712e+00,  1.3940193e-01,
#        -1.4595592e-01,  1.0131936e-01, -6.0336763e-01, -2.2496209e+00,
#         2.7683869e-01, -1.3353598e+00,  1.7290509e-01, -3.4344023e-01,
#        -1.3234684e+00, -3.2031009e-01, -1.4128224e+00,  8.4181142e-01,
#         1.4860911e+00, -9.0320075e-01,  2.5310652e+00, -1.2524999e+00,
#         7.1933037e-01, -1.9183315e-01,  6.1814326e-01,  3.0080331e-03,
#         1.6981035e+00,  2.3298812e-01,  7.1399277e-01,  1.2971867e+00,
#         1.0667654e-01,  6.8296534e-01, -1.9488598e+00,  4.4733793e-01,
#        -1.1554388e+00,  7.5285889e-02,  2.8362912e-01, -7.1851970e-03,
#         4.7101280e-01, -5.2449268e-01, -1.5046262e+00,  8.1634527e-01,
#         7.6971525e-01, -5.8007669e-01, -4.0081370e-01, -1.3503613e+00,
#         5.8721773e-02, -3.4953883e-01,  2.0583980e+00,  2.0833732e-01,
#        -4.3792918e-01, -2.7327821e-01,  4.7412875e-01, -9.4906616e-01,
#        -2.1320188e-01, -9.5298928e-01,  1.4254637e+00,  9.5047021e-01,
#         1.4859064e-01, -2.4249470e+00,  5.2693540e-01, -1.6345031e+00,
#        -4.0084943e-01,  5.8842194e-01, -1.0686442e+00, -1.3602271e+00,
#        -1.6567758e+00,  8.4906310e-01,  6.7332834e-01,  2.1378436e+00,
#         3.5896727e-01,  2.1337423e-01, -1.8830698e+00, -4.4586486e-01,
#        -1.9693288e+00,  1.7159444e+00, -9.8351961e-01,  2.6296892e+00,
#         2.0857556e+00, -5.7576287e-01,  3.6548993e-01,  9.9526834e-01,
#         9.9870193e-01, -6.7876160e-01, -6.7412603e-01,  8.0993897e-01,
#         7.6718664e-01, -1.6468319e+00, -7.6957338e-02,  8.5474628e-01,
#        -2.4676861e-01, -8.2474583e-01, -3.5835677e-01,  3.4864557e-01,
#        -1.2271675e+00,  3.8179429e-03, -9.8818439e-01, -1.2540954e+00,
#        -6.0731155e-01,  1.4253904e+00], dtype=float32)

# %%
# Transforming each sentence into a vector by averaging its word embeddings to address the classification problem.
def avg_word2vec(model,sent) : 
     return np.mean([model.wv[word] for word in sent if word in model.wv.index_to_key ],axis=0)

# %%
X = np.array([avg_word2vec(model, sent) for sent in tqdm(corpus, desc="Processing Sentences")])
# Out:
# Processing Sentences: 100%|██████████| 50000/50000 [07:59<00:00, 104.24it/s]

# %%
X
# Out:
# array([[-3.2805690e-01,  1.1576964e-01,  2.2945741e-02, ...,
#         -5.1859516e-01,  5.4574471e-02, -4.0319967e-01],
#        [-1.8941358e-01, -1.2645641e-01,  1.5103716e-01, ...,
#         -6.6748393e-01,  9.0746731e-02, -3.5737920e-01],
#        [-2.9284549e-01, -2.9590022e-04, -4.8942544e-02, ...,
#         -3.8965854e-01,  2.6219344e-02, -6.7498702e-01],
#        ...,
#        [-2.6333302e-02,  2.5525552e-01, -1.2062365e-01, ...,
#         -3.9388487e-01, -6.4300254e-02, -5.6986189e-01],
#        [-2.9674369e-01, -3.5446901e-02,  1.2522838e-01, ...,
#         -4.5978647e-01,  2.5025839e-01, -2.6778144e-01],
#        [-5.2191299e-01,  1.8569449e-01,  3.2205856e-01, ...,
#         -2.3709612e-01,  3.7495235e-01, -8.8911486e-01]], dtype=float32)

# %%
Gaussian_naive_bayes_model(X , y1)
# Out:
# Accuracy: 0.7635
#               precision    recall  f1-score   support
#
#        False       0.77      0.75      0.76      5035
#         True       0.76      0.77      0.76      4965
#
#     accuracy                           0.76     10000
#    macro avg       0.76      0.76      0.76     10000
# weighted avg       0.76      0.76      0.76     10000
# GaussianNB()

# %% [markdown]
# ######  Word2Vec + GaussianNB (Poor Accuracy)
# ###### ❌ Why does this perform worse?
# ###### Word2Vec embeddings are continuous, dense, and do NOT represent word frequencies.
# ###### GaussianNB assumes feature independence and a Gaussian (normal) distribution, but Word2Vec embeddings don’t follow this assumption.
# ###### Word2Vec captures semantic meaning rather than simple term importance, which is not ideal for Naive Bayes.

# %%
from sklearn.linear_model import LogisticRegression
def logistic_regression_model(X1, y1):
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=0)
    log_reg_classifier = LogisticRegression(max_iter=1000).fit(X_train, y_train)
    y_pred = log_reg_classifier.predict(X_test)
    
    print(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    
    return log_reg_classifier

# %%
from sklearn.svm import SVC
def svm_model(X1, y1):
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=0)
    svm_classifier = SVC(kernel='linear').fit(X_train, y_train)  # Linear kernel
    y_pred = svm_classifier.predict(X_test)
    
    print(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    
    return svm_classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

def random_forest_model(X1, y1):
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=0)
    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=0).fit(X_train, y_train)
    y_pred = rf_classifier.predict(X_test)
    
    print(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    
    return rf_classifier

# %%
random_forest_model(X, y1)
# Out:
#               precision    recall  f1-score    support          model
# False          0.848585  0.815889  0.831916   5035.000  Random Forest
# True           0.820314  0.852367  0.836033   4965.000  Random Forest
# accuracy       0.834000  0.834000  0.834000      0.834  Random Forest
# macro avg      0.834450  0.834128  0.833974  10000.000  Random Forest
# weighted avg   0.834548  0.834000  0.833960  10000.000  Random Forest

# %%
print("SVM model :/n")
svm_model(X, y1)
# Out:
# SVM model :/n
#               precision    recall  f1-score     support model
# False          0.865791  0.863555  0.864671   5035.0000   SVM
# True           0.861993  0.864250  0.863120   4965.0000   SVM
# accuracy       0.863900  0.863900  0.863900      0.8639   SVM
# macro avg      0.863892  0.863902  0.863896  10000.0000   SVM
# weighted avg   0.863905  0.863900  0.863901  10000.0000   SVM

# %%
print("Logistic Regression model :/n")
logistic_regression_model(X, y1)
# Out:
# Logistic Regression model :/n
# 0.8648
#               precision    recall  f1-score   support
#
#        False       0.86      0.87      0.87      5035
#         True       0.87      0.86      0.86      4965
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
# LogisticRegression(max_iter=1000)
